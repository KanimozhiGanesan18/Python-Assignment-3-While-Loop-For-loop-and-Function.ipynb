# %% [markdown]
# <a href="https://colab.research.google.com/github/KanimozhiGanesan18/Python-Assignment-3-While-Loop-For-loop-and-Function.ipynb/blob/main/Python_Assignment_3_While_Loop%2C_For_loop_and_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Task 1: While Loop & Control Statements -Number Guessing Game

import random

secret_number = random.randint(1, 10)

attempts = 3

while attempts > 0:

  guess = int(input("Enter your Guess: "))

  if guess < 1 or guess >10:
    print("Your guess is out of range. Please guess a number between 1 to 10.")
    continue

  attempts -= 1
  if guess == secret_number:
      print("Congratulations ! You Guessed the Correct Number.")
      break
  elif guess > secret_number:
      print("Too high. Try again.")
  else :
      print("Too low. Try again.")

else:
   print("Better luck next time!")
   print("The secret number was:", secret_number)
# Out:
# Enter your Guess: 8
# Too low. Try again.
# Enter your Guess: 15
# Your guess is out of range. Please guess a number between 1 to 10.
# Enter your Guess: 10
# Too high. Try again.
# Enter your Guess: 9
# Congratulations ! You Guessed the Correct Number.

# %%
number = int(input("Enter the number"))


for i in range(1,11):
  result = number * i
  print(f"{number} x {i} = {result}")
# Out:
# Enter the number5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

def calculate_bmi(weight, height):
  bmi = weight / (height ** 2)
  return bmi

bmi = calculate_bmi(weight, height)

print(f"Your BMI is:{bmi:.2f} ")
# Out:
# Enter your weight in kg: 58
# Enter your height in meters: 1.62
# Your BMI is:22.10
